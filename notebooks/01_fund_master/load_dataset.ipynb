# %% [markdown]
# ## fund master

# %%
# day 1 - load csv
import pandas as pd

df = pd.read_csv("../../data/csv_upload/01_fund_master.csv")

print(df.shape)
print()
print(df.dtypes)
print()
df.head()
