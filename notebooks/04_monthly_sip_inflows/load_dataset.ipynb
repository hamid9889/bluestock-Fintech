# %% [markdown]
# ## monthly sip inflows

# %%
# csv load
import pandas as pd

df = pd.read_csv("../../data/csv_upload/04_monthly_sip_inflows.csv")

print(df.shape)
print()
print(df.dtypes)
print()
df.head()
