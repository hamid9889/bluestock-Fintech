# %% [markdown]
# ## portfolio holdings

# %%
# first look at data
import pandas as pd

df = pd.read_csv("../../data/csv_upload/09_portfolio_holdings.csv")

print(df.shape)
print()
print(df.dtypes)
print()
df.head()
