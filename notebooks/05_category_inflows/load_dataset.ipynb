# %% [markdown]
# ## category inflows

# %%
# open dataset
import pandas as pd

df = pd.read_csv("../../data/csv_upload/05_category_inflows.csv")

print(df.shape)
print()
print(df.dtypes)
print()
df.head()
