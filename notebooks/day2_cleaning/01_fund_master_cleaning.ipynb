# %% [markdown]
# # Day 2: 01_fund_master Cleaning
# Basic cleaning and standardization.

# %%
import pandas as pd
import os

raw_path = r'../../data/csv_upload/01_fund_master.csv'
processed_dir = r'../../data/day2_processed/'

df = pd.read_csv(raw_path)
print(f"Initial rows: {len(df)}")
df.head()

# %%
# Basic Cleaning
df = df.drop_duplicates()
# Add specific cleaning logic here if needed

print(f"Final rows: {len(df)}")

# %%
# Save to processed
df.to_csv(os.path.join(processed_dir, 'day2_fund_master_cleaned.csv'day2_), index=False)
print("File saved to data/processed/fund_master_cleaned.csv")
