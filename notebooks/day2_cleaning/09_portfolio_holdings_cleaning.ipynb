# %% [markdown]
# # Day 2: 09_portfolio_holdings Cleaning
# Basic cleaning and standardization.

# %%
import pandas as pd
import os

raw_path = r'../../data/csv_upload/09_portfolio_holdings.csv'
processed_dir = r'../../data/day2_processed/'

df = pd.read_csv(raw_path)
print(f"Initial rows: {len(df)}")
df.head()
# Out:
# Initial rows: 322
#    amfi_code stock_symbol                stock_name       sector  weight_pct  \
# 0     119551    POWERGRID    Power Grid Corporation    Utilities       13.85
# 1     119551     HDFCBANK             HDFC Bank Ltd      Banking       11.19
# 2     119551       GRASIM     Grasim Industries Ltd  Diversified        9.90
# 3     119551      DRREDDY  Dr. Reddy's Laboratories       Pharma        4.76
# 4     119551   ASIANPAINT          Asian Paints Ltd       Paints       10.25
#
#    market_value_cr  current_price_inr portfolio_date
# 0           737.09            6011.08     2025-12-31
# 1            88.97            1074.65     2025-12-31
# 2           208.45            5964.59     2025-12-31
# 3           161.32            3748.82     2025-12-31
# 4           725.90            1321.45     2025-12-31

# %%
# Basic Cleaning
df = df.drop_duplicates()
# Add specific cleaning logic here if needed

print(f"Final rows: {len(df)}")
# Out:
# Final rows: 322

# %%
# Save to processed
df.to_csv(os.path.join(processed_dir, 'day2_portfolio_holdings_cleaned.csv'), index=False)
print("File saved to data/processed/portfolio_holdings_cleaned.csv")
# Out:
# File saved to data/processed/portfolio_holdings_cleaned.csv
