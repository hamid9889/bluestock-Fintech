# %% [markdown]
# # Day 2: 05_category_inflows Cleaning
# Basic cleaning and standardization.

# %%
import pandas as pd
import os

raw_path = r'../../data/csv_upload/05_category_inflows.csv'
processed_dir = r'../../data/day2_processed/'

df = pd.read_csv(raw_path)
print(f"Initial rows: {len(df)}")
df.head()
# Out:
# Initial rows: 144
#      month         category  net_inflow_crore
# 0  2024-04        Large Cap            2413.0
# 1  2024-04          Mid Cap            3897.0
# 2  2024-04        Small Cap            3533.0
# 3  2024-04        Flexi Cap            4947.0
# 4  2024-04  Large & Mid Cap            4214.0

# %%
# Basic Cleaning
df = df.drop_duplicates()
# Add specific cleaning logic here if needed

print(f"Final rows: {len(df)}")
# Out:
# Final rows: 144

# %%
# Save to processed
df.to_csv(os.path.join(processed_dir, 'day2_category_inflows_cleaned.csv'), index=False)
print("File saved to data/processed/category_inflows_cleaned.csv")
# Out:
# File saved to data/processed/category_inflows_cleaned.csv
