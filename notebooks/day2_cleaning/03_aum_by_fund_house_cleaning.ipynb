# %% [markdown]
# # Day 2: 03_aum_by_fund_house Cleaning
# Basic cleaning and standardization.

# %%
import pandas as pd
import os

raw_path = r'../../data/csv_upload/03_aum_by_fund_house.csv'
processed_dir = r'../../data/day2_processed/'

df = pd.read_csv(raw_path)
print(f"Initial rows: {len(df)}")
df.head()
# Out:
# Initial rows: 90
#          date           fund_house  aum_lakh_crore  aum_crore  num_schemes
# 0  2022-03-31      SBI Mutual Fund            6.05     605000          186
# 1  2022-03-31  ICICI Prudential MF            4.65     465000          216
# 2  2022-03-31     HDFC Mutual Fund            4.35     435000          195
# 3  2022-03-31      Nippon India MF            2.70     270000          177
# 4  2022-03-31    Kotak Mahindra MF            2.70     270000          168

# %%
# Basic Cleaning
df = df.drop_duplicates()
# Add specific cleaning logic here if needed

print(f"Final rows: {len(df)}")
# Out:
# Final rows: 90

# %%
# Save to processed
df.to_csv(os.path.join(processed_dir, 'day2_aum_by_fund_house_cleaned.csv'), index=False)
print("File saved to data/processed/aum_by_fund_house_cleaned.csv")
# Out:
# File saved to data/processed/aum_by_fund_house_cleaned.csv
