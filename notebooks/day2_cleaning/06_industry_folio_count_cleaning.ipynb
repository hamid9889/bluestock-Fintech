# %% [markdown]
# # Day 2: 06_industry_folio_count Cleaning
# Basic cleaning and standardization.

# %%
import pandas as pd
import os

raw_path = r'../../data/csv_upload/06_industry_folio_count.csv'
processed_dir = r'../../data/day2_processed/'

df = pd.read_csv(raw_path)
print(f"Initial rows: {len(df)}")
df.head()
# Out:
# Initial rows: 21
#      month  total_folios_crore  equity_folios_crore  debt_folios_crore  \
# 0  2022-01               13.26                 9.28               1.86
# 1  2022-04               13.91                 9.74               1.95
# 2  2022-07               13.85                 9.69               1.94
# 3  2022-10               14.12                 9.88               1.98
# 4  2023-01               14.81                10.37               2.07
#
#    hybrid_folios_crore  others_folios_crore
# 0                 0.80                 1.33
# 1                 0.83                 1.39
# 2                 0.83                 1.38
# 3                 0.85                 1.41
# 4                 0.89                 1.48

# %%
# Basic Cleaning
df = df.drop_duplicates()
# Add specific cleaning logic here if needed

print(f"Final rows: {len(df)}")
# Out:
# Final rows: 21

# %%
# Save to processed
df.to_csv(os.path.join(processed_dir, 'day2_industry_folio_count_cleaned.csv'), index=False)
print("File saved to data/processed/industry_folio_count_cleaned.csv")
# Out:
# File saved to data/processed/industry_folio_count_cleaned.csv
