# %% [markdown]
# # Day 2: 04_monthly_sip_inflows Cleaning
# Basic cleaning and standardization.

# %%
import pandas as pd
import os

raw_path = r'../../data/csv_upload/04_monthly_sip_inflows.csv'
processed_dir = r'../../data/day2_processed/'

df = pd.read_csv(raw_path)
print(f"Initial rows: {len(df)}")
df.head()
# Out:
# Initial rows: 48
#      month  sip_inflow_crore  active_sip_accounts_crore  \
# 0  2022-01             11517                       4.91
# 1  2022-02             11438                       4.93
# 2  2022-03             12328                       5.09
# 3  2022-04             11863                       5.48
# 4  2022-05             12286                       5.55
#
#    new_sip_accounts_lakh  sip_aum_lakh_crore  yoy_growth_pct
# 0                   9.10                4.80             NaN
# 1                   8.20                4.85             NaN
# 2                  10.50                5.01             NaN
# 3                   9.52                5.12             NaN
# 4                   8.10                5.15             NaN

# %%
# Basic Cleaning
df = df.drop_duplicates()
# Add specific cleaning logic here if needed

print(f"Final rows: {len(df)}")
# Out:
# Final rows: 48

# %%
# Save to processed
df.to_csv(os.path.join(processed_dir, 'day2_monthly_sip_inflows_cleaned.csv'), index=False)
print("File saved to data/processed/monthly_sip_inflows_cleaned.csv")
# Out:
# File saved to data/processed/monthly_sip_inflows_cleaned.csv
