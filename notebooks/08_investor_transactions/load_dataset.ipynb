# %% [markdown]
# ## investor transactions

# %%
# importing file
import pandas as pd

df = pd.read_csv("../../data/csv_upload/08_investor_transactions.csv")

print(df.shape)
print()
print(df.dtypes)
print()
df.head()
