# %% [markdown]
# ## aum by fund house

# %%
# load and check
import pandas as pd

df = pd.read_csv("../../data/csv_upload/03_aum_by_fund_house.csv")

print(df.shape)
print()
print(df.dtypes)
print()
df.head()
