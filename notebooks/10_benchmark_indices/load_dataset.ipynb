# %% [markdown]
# ## benchmark indices

# %%
# load file
import pandas as pd

df = pd.read_csv("../../data/csv_upload/10_benchmark_indices.csv")

print(df.shape)
print()
print(df.dtypes)
print()
df.head()
